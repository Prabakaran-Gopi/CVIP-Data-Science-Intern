# %%
pip install missingno
# Out:
# Collecting missingnoNote: you may need to restart the kernel to use updated packages.
#
#   Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: matplotlib in c:\users\prabh\anaconda3\lib\site-packages (from missingno) (3.5.2)
# Requirement already satisfied: seaborn in c:\users\prabh\anaconda3\lib\site-packages (from missingno) (0.11.2)
# Requirement already satisfied: scipy in c:\users\prabh\anaconda3\lib\site-packages (from missingno) (1.9.1)
# Requirement already satisfied: numpy in c:\users\prabh\anaconda3\lib\site-packages (from missingno) (1.24.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\prabh\anaconda3\lib\site-packages (from matplotlib->missingno) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\prabh\anaconda3\lib\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\prabh\anaconda3\lib\site-packages (from matplotlib->missingno) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\prabh\anaconda3\lib\site-packages (from matplotlib->missingno) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\prabh\anaconda3\lib\site-packages (from matplotlib->missingno) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\prabh\anaconda3\lib\site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\prabh\anaconda3\lib\site-packages (from matplotlib->missingno) (1.4.2)
# Requirement already satisfied: pandas>=0.23 in c:\users\prabh\anaconda3\lib\site-packages (from seaborn->missingno) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\prabh\anaconda3\lib\site-packages (from pandas>=0.23->seaborn->missingno) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\prabh\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)
# Installing collected packages: missingno
# Successfully installed missingno-0.5.2

# %%
import pandas as pd
import missingno as msno
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("globalterrorismdb_0718dist.csv", encoding="ISO-8859-1", low_memory=False)

# %%
df.head().iloc[:,100:]
# Out:
#    nkillter  nwound  nwoundus  nwoundte  property  propextent propextent_txt  \
# 0       NaN     0.0       NaN       NaN         0         NaN            NaN
# 1       NaN     0.0       NaN       NaN         0         NaN            NaN
# 2       NaN     0.0       NaN       NaN         0         NaN            NaN
# 3       NaN     NaN       NaN       NaN         1         NaN            NaN
# 4       NaN     NaN       NaN       NaN         1         NaN            NaN
#
#    propvalue propcomment  ishostkid  ...  addnotes  scite1  scite2  scite3  \
# 0        NaN         NaN        0.0  ...       NaN     NaN     NaN     NaN
# 1        NaN         NaN        1.0  ...       NaN     NaN     NaN     NaN
# 2        NaN         NaN        0.0  ...       NaN     NaN     NaN     NaN
# 3        NaN         NaN        0.0  ...       NaN     NaN     NaN     NaN
# 4        NaN         NaN        0.0  ...       NaN     NaN     NaN     NaN
#
#   dbsource INT_LOG  INT_IDEO  INT_MISC  INT_ANY  related
# 0     PGIS       0         0         0        0      NaN
# 1     PGIS       0         1         1        1      NaN
# 2     PGIS      -9        -9         1        1      NaN
# 3     PGIS      -9        -9         1        1      NaN
# 4     PGIS      -9        -9         1        1      NaN
#
# [5 rows x 35 columns]

# %%
df.shape
# Out:
# (181691, 135)

# %%
null_sum=(df.isnull().sum()/len(df))*100
percent_null=null_sum.sort_values(ascending=False)
type(percent_null)
high_null_column=percent_null[percent_null>=50]
less_than_50_null_column=percent_null[~percent_null.isin(high_null_column)]
print(f'Number of column where null value less than fifty percent {len(less_than_50_null_column)}')
less_null_column=less_than_50_null_column.index.to_list()
print(less_null_column)
# Out:
# Number of column where null value less than fifty percent 58
# ['nperps', 'nperpcap', 'nwoundte', 'weapdetail', 'nkillter', 'scite1', 'summary', 'claimed', 'nwoundus', 'nkillus', 'corp1', 'weapsubtype1', 'weapsubtype1_txt', 'nwound', 'targsubtype1', 'targsubtype1_txt', 'nkill', 'longitude', 'latitude', 'natlty1', 'natlty1_txt', 'target1', 'city', 'provstate', 'guncertain1', 'ishostkid', 'specificity', 'doubtterr', 'multiple', 'crit1', 'iyear', 'iday', 'imonth', 'targtype1_txt', 'gname', 'individual', 'dbsource', 'country', 'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY', 'extended', 'region_txt', 'country_txt', 'region', 'crit2', 'targtype1', 'weaptype1', 'weaptype1_txt', 'attacktype1_txt', 'attacktype1', 'vicinity', 'suicide', 'success', 'crit3', 'property', 'eventid']

# %%
new_df=df[less_null_column]

# %%
check=new_df.columns.to_list()

# %%
selected_columns_1=['eventid', 'iyear', 'imonth', 'iday','country_txt','region_txt','city','multiple', 'success', 'suicide', 
 'attacktype1_txt', 'targtype1_txt',  'targsubtype1_txt', 'corp1', 'target1', 'natlty1_txt', 'weaptype1_txt','nkill','nwoundus', 'claimed', 'individual', 'INT_LOG', 'doubtterr', 'INT_MISC', 'specificity','gname', 'ishostkid', 'INT_ANY', 'guncertain1', 'provstate']

# %%
len(check)-len(selected_columns_1)
# Out:
# 28

# %%
print(list((set(check)) - (set(selected_columns_1))))
# Out:
# ['crit2', 'nkillter', 'nwound', 'crit1', 'weapdetail', 'INT_IDEO', 'nperpcap', 'summary', 'weapsubtype1', 'longitude', 'attacktype1', 'natlty1', 'crit3', 'weaptype1', 'country', 'nkillus', 'vicinity', 'nwoundte', 'nperps', 'latitude', 'targsubtype1', 'property', 'dbsource', 'weapsubtype1_txt', 'extended', 'targtype1', 'region', 'scite1']

# %%
df_1=df[selected_columns_1]
df_1.T
# Out:
#                                        0       \
# eventid                          197000000001
# iyear                                    1970
# imonth                                      7
# iday                                        2
# country_txt                Dominican Republic
# region_txt        Central America & Caribbean
# city                            Santo Domingo
# multiple                                  0.0
# success                                     1
# suicide                                     0
# attacktype1_txt                 Assassination
# targtype1_txt     Private Citizens & Property
# targsubtype1_txt               Named Civilian
# corp1                                     NaN
# target1                          Julio Guzman
# natlty1_txt                Dominican Republic
# weaptype1_txt                         Unknown
# nkill                                     1.0
# nwoundus                                  NaN
# claimed                                   NaN
# individual                                  0
# INT_LOG                                     0
# doubtterr                                 0.0
# INT_MISC                                    0
# specificity                               1.0
# gname                                  MANO-D
# ishostkid                                 0.0
# INT_ANY                                     0
# guncertain1                               0.0
# provstate                                 NaN
#
#                                                              1       \
# eventid                                                197000000002
# iyear                                                          1970
# imonth                                                            0
# iday                                                              0
# country_txt                                                  Mexico
# region_txt                                            North America
# city                                                    Mexico city
# multiple                                                        0.0
# success                                                           1
# suicide                                                           0
# attacktype1_txt                         Hostage Taking (Kidnapping)
# targtype1_txt                               Government (Diplomatic)
# targsubtype1_txt  Diplomatic Personnel (outside of embassy, cons...
# corp1                                   Belgian Ambassador Daughter
# target1                                     Nadine Chaval, daughter
# natlty1_txt                                                 Belgium
# weaptype1_txt                                               Unknown
# nkill                                                           0.0
# nwoundus                                                        NaN
# claimed                                                         NaN
# individual                                                        0
# INT_LOG                                                           0
# doubtterr                                                       0.0
# INT_MISC                                                          1
# specificity                                                     1.0
# gname                            23rd of September Communist League
# ishostkid                                                       1.0
# INT_ANY                                                           1
# guncertain1                                                     0.0
# provstate                                                   Federal
#
#                                            2                        3       \
# eventid                              197001000001             197001000002
# iyear                                        1970                     1970
# imonth                                          1                        1
# iday                                            0                        0
# country_txt                           Philippines                   Greece
# region_txt                         Southeast Asia           Western Europe
# city                                      Unknown                   Athens
# multiple                                      0.0                      0.0
# success                                         1                        1
# suicide                                         0                        0
# attacktype1_txt                     Assassination        Bombing/Explosion
# targtype1_txt                 Journalists & Media  Government (Diplomatic)
# targsubtype1_txt  Radio Journalist/Staff/Facility        Embassy/Consulate
# corp1                            Voice of America                      NaN
# target1                                  Employee             U.S. Embassy
# natlty1_txt                         United States            United States
# weaptype1_txt                             Unknown               Explosives
# nkill                                         1.0                      NaN
# nwoundus                                      NaN                      NaN
# claimed                                       NaN                      NaN
# individual                                      0                        0
# INT_LOG                                        -9                       -9
# doubtterr                                     0.0                      0.0
# INT_MISC                                        1                        1
# specificity                                   4.0                      1.0
# gname                                     Unknown                  Unknown
# ishostkid                                     0.0                      0.0
# INT_ANY                                         1                        1
# guncertain1                                   0.0                      0.0
# provstate                                  Tarlac                   Attica
#
#                                           4       \
# eventid                             197001000003
# iyear                                       1970
# imonth                                         1
# iday                                           0
# country_txt                                Japan
# region_txt                             East Asia
# city                                     Fukouka
# multiple                                     0.0
# success                                        1
# suicide                                        0
# attacktype1_txt   Facility/Infrastructure Attack
# targtype1_txt            Government (Diplomatic)
# targsubtype1_txt               Embassy/Consulate
# corp1                                        NaN
# target1                           U.S. Consulate
# natlty1_txt                        United States
# weaptype1_txt                         Incendiary
# nkill                                        NaN
# nwoundus                                     NaN
# claimed                                      NaN
# individual                                     0
# INT_LOG                                       -9
# doubtterr                                   -9.0
# INT_MISC                                       1
# specificity                                  1.0
# gname                                    Unknown
# ishostkid                                    0.0
# INT_ANY                                        1
# guncertain1                                  0.0
# provstate                                Fukouka
#
#                                                            5       \
# eventid                                              197001010002
# iyear                                                        1970
# imonth                                                          1
# iday                                                            1
# country_txt                                         United States
# region_txt                                          North America
# city                                                        Cairo
# multiple                                                      0.0
# success                                                         1
# suicide                                                         0
# attacktype1_txt                                     Armed Assault
# targtype1_txt                                              Police
# targsubtype1_txt  Police Building (headquarters, station, school)
# corp1                                     Cairo Police Department
# target1                                 Cairo Police Headquarters
# natlty1_txt                                         United States
# weaptype1_txt                                            Firearms
# nkill                                                         0.0
# nwoundus                                                      0.0
# claimed                                                       0.0
# individual                                                      0
# INT_LOG                                                        -9
# doubtterr                                                     0.0
# INT_MISC                                                        0
# specificity                                                   1.0
# gname                                          Black Nationalists
# ishostkid                                                     0.0
# INT_ANY                                                        -9
# guncertain1                                                   0.0
# provstate                                                Illinois
#
#                                                              6       \
# eventid                                                197001020001
# iyear                                                          1970
# imonth                                                            1
# iday                                                              2
# country_txt                                                 Uruguay
# region_txt                                            South America
# city                                                     Montevideo
# multiple                                                        0.0
# success                                                           0
# suicide                                                           0
# attacktype1_txt                                       Assassination
# targtype1_txt                                                Police
# targsubtype1_txt                    Police Security Forces/Officers
# corp1                                              Uruguayan Police
# target1           Juan Maria de Lucah/Chief of Directorate of in...
# natlty1_txt                                                 Uruguay
# weaptype1_txt                                              Firearms
# nkill                                                           0.0
# nwoundus                                                        NaN
# claimed                                                         NaN
# individual                                                        0
# INT_LOG                                                           0
# doubtterr                                                       0.0
# INT_MISC                                                          0
# specificity                                                     1.0
# gname                                           Tupamaros (Uruguay)
# ishostkid                                                       0.0
# INT_ANY                                                           0
# guncertain1                                                     0.0
# provstate                                                Montevideo
#
#                                           7       \
# eventid                             197001020002
# iyear                                       1970
# imonth                                         1
# iday                                           2
# country_txt                        United States
# region_txt                         North America
# city                                     Oakland
# multiple                                     0.0
# success                                        1
# suicide                                        0
# attacktype1_txt                Bombing/Explosion
# targtype1_txt                          Utilities
# targsubtype1_txt                     Electricity
# corp1             Pacific Gas & Electric Company
# target1                          Edes Substation
# natlty1_txt                        United States
# weaptype1_txt                         Explosives
# nkill                                        0.0
# nwoundus                                     0.0
# claimed                                      0.0
# individual                                     0
# INT_LOG                                       -9
# doubtterr                                    1.0
# INT_MISC                                       0
# specificity                                  1.0
# gname                                    Unknown
# ishostkid                                    0.0
# INT_ANY                                       -9
# guncertain1                                  0.0
# provstate                             California
#
#                                                              8       \
# eventid                                                197001020003
# iyear                                                          1970
# imonth                                                            1
# iday                                                              2
# country_txt                                           United States
# region_txt                                            North America
# city                                                        Madison
# multiple                                                        0.0
# success                                                           1
# suicide                                                           0
# attacktype1_txt                      Facility/Infrastructure Attack
# targtype1_txt                                              Military
# targsubtype1_txt                Military Recruiting Station/Academy
# corp1                                                      R.O.T.C.
# target1           R.O.T.C. offices at University of Wisconsin, M...
# natlty1_txt                                           United States
# weaptype1_txt                                            Incendiary
# nkill                                                           0.0
# nwoundus                                                        0.0
# claimed                                                         1.0
# individual                                                        0
# INT_LOG                                                           0
# doubtterr                                                       0.0
# INT_MISC                                                          0
# specificity                                                     1.0
# gname                                               New Year's Gang
# ishostkid                                                       0.0
# INT_ANY                                                           0
# guncertain1                                                     0.0
# provstate                                                 Wisconsin
#
#                                                              9       ...  \
# eventid                                                197001030001  ...
# iyear                                                          1970  ...
# imonth                                                            1  ...
# iday                                                              3  ...
# country_txt                                           United States  ...
# region_txt                                            North America  ...
# city                                                        Madison  ...
# multiple                                                        0.0  ...
# success                                                           1  ...
# suicide                                                           0  ...
# attacktype1_txt                      Facility/Infrastructure Attack  ...
# targtype1_txt                                  Government (General)  ...
# targsubtype1_txt                Government Building/Facility/Office  ...
# corp1                                             Selective Service  ...
# target1           Selective Service Headquarters in Madison Wisc...  ...
# natlty1_txt                                           United States  ...
# weaptype1_txt                                            Incendiary  ...
# nkill                                                           0.0  ...
# nwoundus                                                        0.0  ...
# claimed                                                         0.0  ...
# individual                                                        0  ...
# INT_LOG                                                           0  ...
# doubtterr                                                       0.0  ...
# INT_MISC                                                          0  ...
# specificity                                                     1.0  ...
# gname                                               New Year's Gang  ...
# ishostkid                                                       0.0  ...
# INT_ANY                                                           0  ...
# guncertain1                                                     0.0  ...
# provstate                                                 Wisconsin  ...
#
#                                                           181681  \
# eventid                                             201712310016
# iyear                                                       2017
# imonth                                                        12
# iday                                                          31
# country_txt                                          Philippines
# region_txt                                        Southeast Asia
# city                                               Shariff Aguak
# multiple                                                     0.0
# success                                                        1
# suicide                                                        0
# attacktype1_txt                                Bombing/Explosion
# targtype1_txt                                             Police
# targsubtype1_txt  Police Patrol (including vehicles and convoys)
# corp1                           Philippine National Police (PNP)
# target1                                                   Patrol
# natlty1_txt                                          Philippines
# weaptype1_txt                                         Explosives
# nkill                                                        1.0
# nwoundus                                                     0.0
# claimed                                                      0.0
# individual                                                     0
# INT_LOG                                                        0
# doubtterr                                                    0.0
# INT_MISC                                                       0
# specificity                                                  1.0
# gname                 Bangsamoro Islamic Freedom Movement (BIFM)
# ishostkid                                                    0.0
# INT_ANY                                                        0
# guncertain1                                                  0.0
# provstate                                            Maguindanao
#
#                                                         181682  \
# eventid                                           201712310017
# iyear                                                     2017
# imonth                                                      12
# iday                                                        31
# country_txt                                              Italy
# region_txt                                      Western Europe
# city                                                 Spinetoli
# multiple                                                   0.0
# success                                                      1
# suicide                                                      0
# attacktype1_txt                 Facility/Infrastructure Attack
# targtype1_txt                      Private Citizens & Property
# targsubtype1_txt  Refugee (including Camps/IDP/Asylum Seekers)
# corp1                                                  Unknown
# target1                                         Migrant Center
# natlty1_txt                                              Italy
# weaptype1_txt                                       Incendiary
# nkill                                                      0.0
# nwoundus                                                   0.0
# claimed                                                    0.0
# individual                                                   0
# INT_LOG                                                     -9
# doubtterr                                                  0.0
# INT_MISC                                                     0
# specificity                                                1.0
# gname                                                  Unknown
# ishostkid                                                  0.0
# INT_ANY                                                     -9
# guncertain1                                                0.0
# provstate                                               Marche
#
#                                             181683  \
# eventid                               201712310018
# iyear                                         2017
# imonth                                          12
# iday                                            31
# country_txt                            Afghanistan
# region_txt                              South Asia
# city                             Kohistan district
# multiple                                       0.0
# success                                          1
# suicide                                          0
# attacktype1_txt                      Armed Assault
# targtype1_txt         Terrorists/Non-State Militia
# targsubtype1_txt                 Non-State Militia
# corp1             National Uprising Movement (NUM)
# target1                            House of Member
# natlty1_txt                            Afghanistan
# weaptype1_txt                             Firearms
# nkill                                          6.0
# nwoundus                                       0.0
# claimed                                        0.0
# individual                                       0
# INT_LOG                                          0
# doubtterr                                      0.0
# INT_MISC                                         0
# specificity                                    3.0
# gname                                      Taliban
# ishostkid                                      0.0
# INT_ANY                                          0
# guncertain1                                    0.0
# provstate                                   Faryab
#
#                                                              181684  \
# eventid                                                201712310019
# iyear                                                          2017
# imonth                                                           12
# iday                                                             31
# country_txt                                                   India
# region_txt                                               South Asia
# city                                                        Hungrum
# multiple                                                        0.0
# success                                                           1
# suicide                                                           0
# attacktype1_txt                         Hostage Taking (Kidnapping)
# targtype1_txt                                  Government (General)
# targsubtype1_txt  Politician or Political Party Movement/Meeting...
# corp1                                   NC Hills Autonomous Council
# target1           Personal Security Officer of Council Member Ih...
# natlty1_txt                                                   India
# weaptype1_txt                                              Firearms
# nkill                                                           0.0
# nwoundus                                                        0.0
# claimed                                                         0.0
# individual                                                        0
# INT_LOG                                                           0
# doubtterr                                                       0.0
# INT_MISC                                                          0
# specificity                                                     2.0
# gname                                      Zeliangrong United Front
# ishostkid                                                       1.0
# INT_ANY                                                           0
# guncertain1                                                     0.0
# provstate                                                     Assam
#
#                                  181685                      181686  \
# eventid                    201712310020                201712310022
# iyear                              2017                        2017
# imonth                               12                          12
# iday                                 31                          31
# country_txt                 Afghanistan                     Somalia
# region_txt                   South Asia          Sub-Saharan Africa
# city                            Maymana               Ceelka Geelow
# multiple                            0.0                         0.0
# success                               1                           1
# suicide                               0                           0
# attacktype1_txt       Bombing/Explosion               Armed Assault
# targtype1_txt                  Business                    Military
# targsubtype1_txt  Retail/Grocery/Bakery         Military Checkpoint
# corp1                           Unknown  Somali National Army (SNA)
# target1                    Jewelry Shop                  Checkpoint
# natlty1_txt                 Afghanistan                     Somalia
# weaptype1_txt                Explosives                    Firearms
# nkill                               0.0                         1.0
# nwoundus                            0.0                         0.0
# claimed                             0.0                         1.0
# individual                            0                           0
# INT_LOG                              -9                           0
# doubtterr                           0.0                         1.0
# INT_MISC                              0                           0
# specificity                         1.0                         2.0
# gname                           Unknown                  Al-Shabaab
# ishostkid                           0.0                         0.0
# INT_ANY                              -9                           0
# guncertain1                         0.0                         0.0
# provstate                        Faryab             Middle Shebelle
#
#                                                          181687  \
# eventid                                            201712310029
# iyear                                                      2017
# imonth                                                       12
# iday                                                         31
# country_txt                                               Syria
# region_txt                           Middle East & North Africa
# city                                                     Jableh
# multiple                                                    0.0
# success                                                       1
# suicide                                                       0
# attacktype1_txt                               Bombing/Explosion
# targtype1_txt                                          Military
# targsubtype1_txt  Military Barracks/Base/Headquarters/Checkpost
# corp1                                         Russian Air Force
# target1                                        Hmeymim Air Base
# natlty1_txt                                              Russia
# weaptype1_txt                                        Explosives
# nkill                                                       2.0
# nwoundus                                                    0.0
# claimed                                                     0.0
# individual                                                    0
# INT_LOG                                                      -9
# doubtterr                                                   1.0
# INT_MISC                                                      1
# specificity                                                 1.0
# gname                                         Muslim extremists
# ishostkid                                                   0.0
# INT_ANY                                                       1
# guncertain1                                                 0.0
# provstate                                              Lattakia
#
#                                                       181688  \
# eventid                                         201712310030
# iyear                                                   2017
# imonth                                                    12
# iday                                                      31
# country_txt                                      Philippines
# region_txt                                    Southeast Asia
# city                                                Kubentog
# multiple                                                 0.0
# success                                                    1
# suicide                                                    0
# attacktype1_txt               Facility/Infrastructure Attack
# targtype1_txt                    Private Citizens & Property
# targsubtype1_txt                   House/Apartment/Residence
# corp1                                         Not Applicable
# target1                                               Houses
# natlty1_txt                                      Philippines
# weaptype1_txt                                     Incendiary
# nkill                                                    0.0
# nwoundus                                                 0.0
# claimed                                                  0.0
# individual                                                 0
# INT_LOG                                                    0
# doubtterr                                                0.0
# INT_MISC                                                   0
# specificity                                              2.0
# gname             Bangsamoro Islamic Freedom Movement (BIFM)
# ishostkid                                                0.0
# INT_ANY                                                    0
# guncertain1                                              0.0
# provstate                                        Maguindanao
#
#                                                181689             181690
# eventid                                  201712310031       201712310032
# iyear                                            2017               2017
# imonth                                             12                 12
# iday                                               31                 31
# country_txt                                     India        Philippines
# region_txt                                 South Asia     Southeast Asia
# city                                           Imphal      Cotabato City
# multiple                                          0.0                0.0
# success                                             0                  0
# suicide                                             0                  0
# attacktype1_txt                     Bombing/Explosion  Bombing/Explosion
# targtype1_txt                    Government (General)            Unknown
# targsubtype1_txt  Government Building/Facility/Office                NaN
# corp1                       Forest Department Manipur            Unknown
# target1                                        Office            Unknown
# natlty1_txt                                     India        Philippines
# weaptype1_txt                              Explosives         Explosives
# nkill                                             0.0                0.0
# nwoundus                                          0.0                0.0
# claimed                                           0.0                0.0
# individual                                          0                  0
# INT_LOG                                            -9                 -9
# doubtterr                                         0.0                0.0
# INT_MISC                                            0                  0
# specificity                                       1.0                1.0
# gname                                         Unknown            Unknown
# ishostkid                                         0.0                0.0
# INT_ANY                                            -9                 -9
# guncertain1                                       0.0                0.0
# provstate                                     Manipur        Maguindanao
#
# [30 rows x 181691 columns]

# %%
(df_1.isnull().sum()/len(df_1))*100
# Out:
# eventid              0.000000
# iyear                0.000000
# imonth               0.000000
# iday                 0.000000
# country_txt          0.000000
# region_txt           0.000000
# city                 0.238867
# multiple             0.000550
# success              0.000000
# suicide              0.000000
# attacktype1_txt      0.000000
# targtype1_txt        0.000000
# targsubtype1_txt     5.709144
# corp1               23.418882
# target1              0.350045
# natlty1_txt          0.858050
# weaptype1_txt        0.000000
# nkill                5.676120
# nwoundus            35.611010
# claimed             36.391456
# individual           0.000000
# INT_LOG              0.000000
# doubtterr            0.000550
# INT_MISC             0.000000
# specificity          0.003302
# gname                0.000000
# ishostkid            0.097969
# INT_ANY              0.000000
# guncertain1          0.209146
# provstate            0.231712
# dtype: float64

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 30 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   eventid           181691 non-null  int64
#  1   iyear             181691 non-null  int64
#  2   imonth            181691 non-null  int64
#  3   iday              181691 non-null  int64
#  4   country_txt       181691 non-null  object
#  5   region_txt        181691 non-null  object
#  6   city              181257 non-null  object
#  7   multiple          181690 non-null  float64
#  8   success           181691 non-null  int64
#  9   suicide           181691 non-null  int64
#  10  attacktype1_txt   181691 non-null  object
#  11  targtype1_txt     181691 non-null  object
#  12  targsubtype1_txt  171318 non-null  object
#  13  corp1             139141 non-null  object
#  14  target1           181055 non-null  object
#  15  natlty1_txt       180132 non-null  object
#  16  weaptype1_txt     181691 non-null  object
#  17  nkill             171378 non-null  float64
#  18  nwoundus          116989 non-null  float64
#  19  claimed           115571 non-null  float64
#  20  individual        181691 non-null  int64
#  21  INT_LOG           181691 non-null  int64
#  22  doubtterr         181690 non-null  float64
#  23  INT_MISC          181691 non-null  int64
#  24  specificity       181685 non-null  float64
#  25  gname             181691 non-null  object
#  26  ishostkid         181513 non-null  float64
#  27  INT_ANY           181691 non-null  int64
#  28  guncertain1       181311 non-null  float64
#  29  provstate         181270 non-null  object
# dtypes: float64(8), int64(10), object(12)
# memory usage: 41.6+ MB

# %%
attack_per_year=df_1['iyear'].value_counts()

# %%
ax=plt.rcParams['figure.figsize'] = 20,7.27
ax=sns.countplot(x='iyear',data=df_1)
ax.set_xlabel('Year',fontsize=20)
plt.xticks(rotation = 35)
ax.set_ylabel('Count of Attack',fontsize=20)
ax.set_title('Terrorist Attack/Year',fontsize=22);

# %%
ax=plt.rcParams['figure.figsize'] = 22,8.27
ax=sns.countplot(x='country_txt',data=df_1,order = df_1['country_txt'].value_counts().index[:30])
ax.set_xlabel('Country',fontsize=20)
plt.xticks(rotation = 75)
ax.set_ylabel('Count of Terrorist Attack',fontsize=20)
ax.set_title('Top 30 Countey via Numbers of Attacks',fontsize=22);

# %%
ax=plt.rcParams['figure.figsize'] = 16,8.27
ax=sns.countplot(x='targtype1_txt',data=df_1,order = df_1['targtype1_txt'].value_counts().index)
ax.set_xlabel('Type of Targets',fontsize=18)
plt.xticks(rotation = 75)
ax.set_ylabel('Count',fontsize=18)
ax.set_title('Most Frequent Target of Terrorist',fontsize=20);

# %%
df_1['gname'].value_counts()
# Out:
# Unknown                                             82782
# Taliban                                              7478
# Islamic State of Iraq and the Levant (ISIL)          5613
# Shining Path (SL)                                    4555
# Farabundo Marti National Liberation Front (FMLN)     3351
#                                                     ...
# Ansar Sarallah                                          1
# Sword of Islam                                          1
# Support of Ocalan-The Hawks of Thrace                   1
# Arab Revolutionary Front                                1
# MANO-D                                                  1
# Name: gname, Length: 3537, dtype: int64

# %%
suceess_country=df_1.groupby('country_txt').agg({'eventid':'count','success':'sum'}).reset_index()
suceess_country.columns=['Country','Total_Attacks','Attack_Success']
suceess_country['Attack_Failed']=suceess_country['Total_Attacks']-suceess_country['Attack_Success']
suceess_country['Failure_Rate_Attack']=(suceess_country['Attack_Failed']/suceess_country['Total_Attacks'])*100
suceess_country['Success_Rate_Attack']=(suceess_country['Attack_Success']/suceess_country['Total_Attacks'])*100
suceess_country=suceess_country.round(2)

# %%
able_stop_terror_attack=suceess_country[suceess_country['Total_Attacks']>=5].sort_values('Failure_Rate_Attack',ascending=False )[:10]
plot_able_stop_terror_attack=able_stop_terror_attack.loc[:,['Country','Failure_Rate_Attack']]
ax=plt.rcParams['figure.figsize'] = 16,8.27
ax=sns.barplot(x='Country',y='Failure_Rate_Attack',data=plot_able_stop_terror_attack)
ax.set_xlabel('Countries',fontsize=18)
plt.xticks(rotation = 75)
ax.set_ylabel('Rate of Failure of Terror Attack',fontsize=18)
ax.set_title('Top 10 Countries Able to Succefull Tackle  Terrorist Attack("More Than 5 Attack")',fontsize=20);

# %%
attack_per_year=df_1.groupby(['iyear','targtype1_txt','target1','success','weaptype1_txt','gname'])['eventid'].count().to_frame(name = 'Total_Attacks').reset_index()

# %%
ax = sns.relplot(col="weaptype1_txt", y="Total_Attacks",col_wrap=4, hue='weaptype1_txt',x="iyear",kind='line', ci=None ,data=attack_per_year, height=3, aspect=1.5, legend=False)

# %%
ax = sns.lineplot(x="iyear", y="Total_Attacks", hue='success', ci=None ,data=attack_per_year)
ax.tick_params(rotation=45)
